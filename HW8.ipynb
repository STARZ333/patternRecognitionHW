# %% [markdown]
# B0829027鄭星逸

# %% [markdown]
# This is a companion notebook for the book [Deep Learning with Python, Second Edition](https://www.manning.com/books/deep-learning-with-python-second-edition?a_aid=keras&a_bid=76564dff). For readability, it only contains runnable code blocks and section titles, and omits everything else in the book: text paragraphs, figures, and pseudocode.
#
# **If you want to be able to follow what's going on, I recommend reading the notebook side by side with your copy of the book.**
#
# This notebook was generated for TensorFlow 2.6.

# %% [markdown]
# # Introduction to deep learning for computer vision

# %% [markdown]
# ## Introduction to convnets

# %% [markdown]
# **Instantiating a small convnet**

# %%
from tensorflow import keras
from tensorflow.keras import layers
inputs = keras.Input(shape=(28, 28, 1))
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(inputs)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
outputs = layers.Dense(10, activation="softmax")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

# %% [markdown]
# **Displaying the model's summary**

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 3, 3, 128)         73856
#
#  flatten (Flatten)           (None, 1152)              0
#
#  dense (Dense)               (None, 10)                11530
#
# =================================================================
# Total params: 104,202
# Trainable params: 104,202
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Training the convnet on MNIST images**

# %%
from tensorflow.keras.datasets import mnist

(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
train_images = train_images.reshape((60000, 28, 28, 1))
train_images = train_images.astype("float32") / 255
test_images = test_images.reshape((10000, 28, 28, 1))
test_images = test_images.astype("float32") / 255
model.compile(optimizer="rmsprop",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"])
model.fit(train_images, train_labels, epochs=5, batch_size=64)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 2s 0us/step
# 11501568/11490434 [==============================] - 2s 0us/step
# Epoch 1/5
# 938/938 [==============================] - 10s 5ms/step - loss: 0.1563 - accuracy: 0.9514
# Epoch 2/5
# 938/938 [==============================] - 5s 5ms/step - loss: 0.0435 - accuracy: 0.9868
# Epoch 3/5
# 938/938 [==============================] - 5s 5ms/step - loss: 0.0298 - accuracy: 0.9908
# Epoch 4/5
# 938/938 [==============================] - 5s 5ms/step - loss: 0.0219 - accuracy: 0.9932
# Epoch 5/5
# 938/938 [==============================] - 5s 5ms/step - loss: 0.0171 - accuracy: 0.9947

# %% [markdown]
# **Evaluating the convnet**

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0216 - accuracy: 0.9928
# Test accuracy: 0.993

# %% [markdown]
# ### The convolution operation

# %% [markdown]
# #### Understanding border effects and padding

# %% [markdown]
# #### Understanding convolution strides

# %% [markdown]
# ### The max-pooling operation

# %% [markdown]
# **An incorrectly structured convnet missing its max-pooling layers**

# %%
inputs = keras.Input(shape=(28, 28, 1))
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(inputs)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
outputs = layers.Dense(10, activation="softmax")(x)
model_no_max_pool = keras.Model(inputs=inputs, outputs=outputs)

# %%
model_no_max_pool.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_3 (Conv2D)           (None, 26, 26, 32)        320
#
#  conv2d_4 (Conv2D)           (None, 24, 24, 64)        18496
#
#  conv2d_5 (Conv2D)           (None, 22, 22, 128)       73856
#
#  flatten_1 (Flatten)         (None, 61952)             0
#
#  dense_1 (Dense)             (None, 10)                619530
#
# =================================================================
# Total params: 712,202
# Trainable params: 712,202
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Training a convnet from scratch on a small dataset

# %% [markdown]
# ### The relevance of deep learning for small-data problems

# %% [markdown]
# ### Downloading the data

# %%
from google.colab import files
files.upload()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18784/1613494533.py in <module>
# ----> 1 from google.colab import files
#       2 files.upload()
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle competitions download -c dogs-vs-cats

# %%
# !unzip -qq train.zip

# %%
/out.png

# %% [markdown]
# **Copying images to training, validation, and test directories**

# %%
import os, shutil, pathlib

original_dir = pathlib.Path("train")
new_base_dir = pathlib.Path("cats_vs_dogs_small")

def make_subset(subset_name, start_index, end_index):
    for category in ("cat", "dog"):
        dir = new_base_dir / subset_name / category
        os.makedirs(dir)
        fnames = [f"{category}.{i}.jpg" for i in range(start_index, end_index)]
        for fname in fnames:
            shutil.copyfile(src=original_dir / fname,
                            dst=dir / fname)

make_subset("train", start_index=0, end_index=1000)
make_subset("validation", start_index=1000, end_index=1500)
make_subset("test", start_index=1500, end_index=2500)

# %% [markdown]
# ### Building the model

# %% [markdown]
# **Instantiating a small convnet for dogs vs. cats classification**

# %%
from tensorflow import keras
from tensorflow.keras import layers

inputs = keras.Input(shape=(180, 180, 3))
x = layers.Rescaling(1./255)(inputs)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 180, 180, 3)]     0
#
#  rescaling_1 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_11 (Conv2D)          (None, 178, 178, 32)      896
#
#  max_pooling2d_6 (MaxPooling  (None, 89, 89, 32)       0
#  2D)
#
#  conv2d_12 (Conv2D)          (None, 87, 87, 64)        18496
#
#  max_pooling2d_7 (MaxPooling  (None, 43, 43, 64)       0
#  2D)
#
#  conv2d_13 (Conv2D)          (None, 41, 41, 128)       73856
#
#  max_pooling2d_8 (MaxPooling  (None, 20, 20, 128)      0
#  2D)
#
#  conv2d_14 (Conv2D)          (None, 18, 18, 256)       295168
#
#  max_pooling2d_9 (MaxPooling  (None, 9, 9, 256)        0
#  2D)
#
#  conv2d_15 (Conv2D)          (None, 7, 7, 256)         590080
#
#  flatten_3 (Flatten)         (None, 12544)             0
#
#  dense_3 (Dense)             (None, 1)                 12545
#
# =================================================================
# Total params: 991,041
# Trainable params: 991,041
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Configuring the model for training**

# %%
model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

# %% [markdown]
# ### Data preprocessing

# %% [markdown]
# **Using `image_dataset_from_directory` to read images**

# %%
from tensorflow.keras.utils import image_dataset_from_directory

train_dataset = image_dataset_from_directory(
    new_base_dir / "train",
    image_size=(180, 180),
    batch_size=32)
validation_dataset = image_dataset_from_directory(
    new_base_dir / "validation",
    image_size=(180, 180),
    batch_size=32)
test_dataset = image_dataset_from_directory(
    new_base_dir / "test",
    image_size=(180, 180),
    batch_size=32)
# Out:
# Found 2000 files belonging to 2 classes.
# Found 1000 files belonging to 2 classes.
# Found 2000 files belonging to 2 classes.

# %%
import numpy as np
import tensorflow as tf
random_numbers = np.random.normal(size=(1000, 16))
dataset = tf.data.Dataset.from_tensor_slices(random_numbers)

# %%
for i, element in enumerate(dataset):
    print(element.shape)
    if i >= 2:
        break
# Out:
# (16,)
# (16,)
# (16,)

# %%
batched_dataset = dataset.batch(32)
for i, element in enumerate(batched_dataset):
    print(element.shape)
    if i >= 2:
        break
# Out:
# (32, 16)
# (32, 16)
# (32, 16)

# %%
reshaped_dataset = dataset.map(lambda x: tf.reshape(x, (4, 4)))
for i, element in enumerate(reshaped_dataset):
    print(element.shape)
    if i >= 2:
        break
# Out:
# (4, 4)
# (4, 4)
# (4, 4)

# %% [markdown]
# **Displaying the shapes of the data and labels yielded by the `Dataset`**

# %%
for data_batch, labels_batch in train_dataset:
    print("data batch shape:", data_batch.shape)
    print("labels batch shape:", labels_batch.shape)
    break
# Out:
# data batch shape: (32, 180, 180, 3)
# labels batch shape: (32,)

# %% [markdown]
# **Fitting the model using a `Dataset`**

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="convnet_from_scratch.keras",
        save_best_only=True,
        monitor="val_loss")
]
history = model.fit(
    train_dataset,
    epochs=30,
    validation_data=validation_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/30
# 63/63 [==============================] - 3s 36ms/step - loss: 0.7592 - accuracy: 0.5110 - val_loss: 0.6928 - val_accuracy: 0.5000
# Epoch 2/30
# 63/63 [==============================] - 2s 30ms/step - loss: 0.6952 - accuracy: 0.5460 - val_loss: 1.2648 - val_accuracy: 0.5000
# Epoch 3/30
# 63/63 [==============================] - 2s 31ms/step - loss: 0.7020 - accuracy: 0.5695 - val_loss: 0.6783 - val_accuracy: 0.5670
# Epoch 4/30
# 63/63 [==============================] - 2s 31ms/step - loss: 0.6612 - accuracy: 0.6365 - val_loss: 0.6761 - val_accuracy: 0.5740
# Epoch 5/30
# 63/63 [==============================] - 2s 31ms/step - loss: 0.6366 - accuracy: 0.6510 - val_loss: 0.6362 - val_accuracy: 0.6350
# Epoch 6/30
# 63/63 [==============================] - 2s 30ms/step - loss: 0.5945 - accuracy: 0.6830 - val_loss: 0.8392 - val_accuracy: 0.5880
# Epoch 7/30
# 63/63 [==============================] - 2s 30ms/step - loss: 0.5646 - accuracy: 0.7110 - val_loss: 0.5857 - val_accuracy: 0.6890
# Epoch 8/30
# 63/63 [==============================] - 2s 30ms/step - loss: 0.5282 - accuracy: 0.7415 - val_loss: 0.5880 - val_accuracy: 0.7200
# Epoch 9/30
# 63/63 [==============================] - 2s 31ms/step - loss: 0.4812 - accuracy: 0.7720 - val_loss: 0.5669 - val_accuracy: 0.7270
# Epoch 10/30
# 63/63 [==============================] - 2s 30ms/step - loss: 0.4583 - accuracy: 0.7850 - val_loss: 0.5497 - val_accuracy: 0.7330
# Epoch 11/30
# 63/63 [==============================] - 2s 30ms/step - loss: 0.4014 - accuracy: 0.8280 - val_loss: 0.6277 - val_accuracy: 0.6980
# Epoch 12/30
# 63/63 [==============================] - 2s 30ms/step - loss: 0.3658 - accuracy: 0.8430 - val_loss: 0.7674 - val_accuracy: 0.6970
# Epoch 13/30
# 63/63 [==============================] - 2s 30ms/step - loss: 0.3168 - accuracy: 0.8535 - val_loss: 0.6669 - val_accuracy: 0.7360
# Epoch 14/30
# 63/63 [==============================] - 2s 30ms/step - loss: 0.2609 - accuracy: 0.8915 - val_loss: 0.8967 - val_accuracy: 0.7010
# Epoch 15/30
# 63/63 [==============================] - 2s 30ms/step - loss: 0.2357 - accuracy: 0.8990 - val_loss: 0.6929 - val_accuracy: 0.7530
# Epoch 16/30
# 63/63 [==============================] - 2s 30ms/step - loss: 0.1723 - accuracy: 0.9340 - val_loss: 0.9225 - val_accuracy: 0.7490
# Epoch 17/30
# 63/63 [==============================] - 2s 30ms/step - loss: 0.1611 - accuracy: 0.9380 - val_loss: 0.9833 - val_accuracy: 0.7460
# Epoch 18/30
# 63/63 [==============================] - 2s 30ms/step - loss: 0.1140 - accuracy: 0.9565 - val_loss: 1.2005 - val_accuracy: 0.7230
# Epoch 19/30
# 63/63 [==============================] - 2s 30ms/step - loss: 0.0858 - accuracy: 0.9650 - val_loss: 1.2382 - val_accuracy: 0.7320
# Epoch 20/30
# 63/63 [==============================] - 2s 30ms/step - loss: 0.0948 - accuracy: 0.9650 - val_loss: 1.1850 - val_accuracy: 0.7260
# Epoch 21/30
# 63/63 [==============================] - 2s 30ms/step - loss: 0.0796 - accuracy: 0.9695 - val_loss: 1.2177 - val_accuracy: 0.7310
# Epoch 22/30
# 63/63 [==============================] - 2s 30ms/step - loss: 0.0612 - accuracy: 0.9795 - val_loss: 1.4960 - val_accuracy: 0.7570
# Epoch 23/30
# 63/63 [==============================] - 2s 30ms/step - loss: 0.0792 - accuracy: 0.9755 - val_loss: 1.3243 - val_accuracy: 0.7460
# Epoch 24/30
# 63/63 [==============================] - 2s 30ms/step - loss: 0.0496 - accuracy: 0.9850 - val_loss: 1.7415 - val_accuracy: 0.7330
# Epoch 25/30
# 63/63 [==============================] - 2s 30ms/step - loss: 0.0567 - accuracy: 0.9805 - val_loss: 1.8940 - val_accuracy: 0.7500
# Epoch 26/30
# 63/63 [==============================] - 2s 29ms/step - loss: 0.0651 - accuracy: 0.9815 - val_loss: 1.4327 - val_accuracy: 0.7300
# Epoch 27/30
# 63/63 [==============================] - 2s 29ms/step - loss: 0.0477 - accuracy: 0.9855 - val_loss: 1.5457 - val_accuracy: 0.7480
# Epoch 28/30
# 63/63 [==============================] - 2s 30ms/step - loss: 0.0673 - accuracy: 0.9815 - val_loss: 1.5884 - val_accuracy: 0.7000
# Epoch 29/30
# 63/63 [==============================] - 2s 30ms/step - loss: 0.0373 - accuracy: 0.9890 - val_loss: 1.5948 - val_accuracy: 0.7350
# Epoch 30/30
# 63/63 [==============================] - 2s 30ms/step - loss: 0.0248 - accuracy: 0.9930 - val_loss: 2.3550 - val_accuracy: 0.7140

# %% [markdown]
# **Displaying curves of loss and accuracy during training**

# %%
import matplotlib.pyplot as plt
accuracy = history.history["accuracy"]
val_accuracy = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(accuracy) + 1)
plt.plot(epochs, accuracy, "bo", label="Training accuracy")
plt.plot(epochs, val_accuracy, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %% [markdown]
# **Evaluating the model on the test set**

# %%
test_model = keras.models.load_model("convnet_from_scratch.keras")
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 63/63 [==============================] - 1s 15ms/step - loss: 0.5527 - accuracy: 0.7280
# Test accuracy: 0.728

# %% [markdown]
# ### Using data augmentation

# %% [markdown]
# **Define a data augmentation stage to add to an image model**

# %%
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.1),
        layers.RandomZoom(0.2),
    ]
)

# %% [markdown]
# **Displaying some randomly augmented training images**

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_dataset.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.axis("off")

# %% [markdown]
# **Defining a new convnet that includes image augmentation and dropout**

# %%
inputs = keras.Input(shape=(180, 180, 3))
x = data_augmentation(inputs)
x = layers.Rescaling(1./255)(x)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

# %% [markdown]
# **Training the regularized convnet**

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="convnet_from_scratch_with_augmentation.keras",
        save_best_only=True,
        monitor="val_loss")
]
history = model.fit(
    train_dataset,
    epochs=100,
    validation_data=validation_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/100
# 63/63 [==============================] - 3s 34ms/step - loss: 0.7020 - accuracy: 0.5120 - val_loss: 0.6893 - val_accuracy: 0.5280
# Epoch 2/100
# 63/63 [==============================] - 2s 30ms/step - loss: 0.6945 - accuracy: 0.5275 - val_loss: 0.6591 - val_accuracy: 0.6160
# Epoch 3/100
# 63/63 [==============================] - 2s 30ms/step - loss: 0.6836 - accuracy: 0.5805 - val_loss: 0.6493 - val_accuracy: 0.6150
# Epoch 4/100
# 63/63 [==============================] - 2s 30ms/step - loss: 0.6650 - accuracy: 0.6245 - val_loss: 0.6412 - val_accuracy: 0.6320
# Epoch 5/100
# 63/63 [==============================] - 2s 30ms/step - loss: 0.6384 - accuracy: 0.6535 - val_loss: 0.6008 - val_accuracy: 0.6790
# Epoch 6/100
# 63/63 [==============================] - 2s 29ms/step - loss: 0.6313 - accuracy: 0.6535 - val_loss: 0.6233 - val_accuracy: 0.6300
# Epoch 7/100
# 63/63 [==============================] - 2s 29ms/step - loss: 0.6109 - accuracy: 0.6720 - val_loss: 0.6269 - val_accuracy: 0.6490
# Epoch 8/100
# 63/63 [==============================] - 2s 30ms/step - loss: 0.6040 - accuracy: 0.6835 - val_loss: 0.6041 - val_accuracy: 0.6730
# Epoch 9/100
# 63/63 [==============================] - 2s 30ms/step - loss: 0.5843 - accuracy: 0.6825 - val_loss: 0.8093 - val_accuracy: 0.6470
# Epoch 10/100
# 63/63 [==============================] - 2s 30ms/step - loss: 0.5794 - accuracy: 0.6975 - val_loss: 0.5426 - val_accuracy: 0.7300
# Epoch 11/100
# 63/63 [==============================] - 2s 30ms/step - loss: 0.5557 - accuracy: 0.7150 - val_loss: 0.5448 - val_accuracy: 0.7310
# Epoch 12/100
# 63/63 [==============================] - 2s 30ms/step - loss: 0.5470 - accuracy: 0.7280 - val_loss: 0.6202 - val_accuracy: 0.6800
# Epoch 13/100
# 63/63 [==============================] - 2s 30ms/step - loss: 0.5528 - accuracy: 0.7325 - val_loss: 0.5264 - val_accuracy: 0.7470
# Epoch 14/100
# 63/63 [==============================] - 2s 30ms/step - loss: 0.5167 - accuracy: 0.7655 - val_loss: 0.5410 - val_accuracy: 0.7460
# Epoch 15/100
# 63/63 [==============================] - 2s 30ms/step - loss: 0.5019 - accuracy: 0.7570 - val_loss: 0.6438 - val_accuracy: 0.6620
# Epoch 16/100
# 63/63 [==============================] - 2s 32ms/step - loss: 0.2260 - accuracy: 0.9300 - val_loss: 0.9732 - val_accuracy: 0.7890
# Epoch 94/100
# 63/63 [==============================] - 2s 32ms/step - loss: 0.2045 - accuracy: 0.9280 - val_loss: 0.8223 - val_accuracy: 0.8270
# Epoch 95/100
# 63/63 [==============================] - 2s 32ms/step - loss: 0.2024 - accuracy: 0.9310 - val_loss: 0.9642 - val_accuracy: 0.7900
# Epoch 96/100
# 63/63 [==============================] - 2s 33ms/step - loss: 0.2039 - accuracy: 0.9270 - val_loss: 0.6927 - val_accuracy: 0.8220
# Epoch 97/100
# 63/63 [==============================] - 2s 33ms/step - loss: 0.2137 - accuracy: 0.9240 - val_loss: 0.5885 - val_accuracy: 0.8570
# Epoch 98/100
# 63/63 [==============================] - 2s 32ms/step - loss: 0.1969 - accuracy: 0.9315 - val_loss: 0.8307 - val_accuracy: 0.8390
# Epoch 99/100
# 63/63 [==============================] - 2s 32ms/step - loss: 0.1954 - accuracy: 0.9345 - val_loss: 0.8023 - val_accuracy: 0.8490
# Epoch 100/100
# 63/63 [==============================] - 2s 33ms/step - loss: 0.2039 - accuracy: 0.9250 - val_loss: 0.9693 - val_accuracy: 0.8210

# %% [markdown]
# **Evaluating the model on the test set**

# %%
test_model = keras.models.load_model(
    "convnet_from_scratch_with_augmentation.keras")
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 63/63 [==============================] - 1s 13ms/step - loss: 0.4419 - accuracy: 0.8040
# Test accuracy: 0.804

# %% [markdown]
# ## Leveraging a pretrained model

# %% [markdown]
# ### Feature extraction with a pretrained model

# %% [markdown]
# **Instantiating the VGG16 convolutional base**

# %%
conv_base = keras.applications.vgg16.VGG16(
    weights="imagenet",
    include_top=False,
    input_shape=(180, 180, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 9s 0us/step
# 58900480/58889256 [==============================] - 9s 0us/step

# %%
conv_base.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 180, 180, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 180, 180, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 180, 180, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 90, 90, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 90, 90, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 90, 90, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 45, 45, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 45, 45, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 45, 45, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 45, 45, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 22, 22, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 22, 22, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 22, 22, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 22, 22, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 11, 11, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 11, 11, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 11, 11, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 11, 11, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 5, 5, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Fast feature extraction without data augmentation

# %% [markdown]
# **Extracting the VGG16 features and corresponding labels**

# %%
import numpy as np

def get_features_and_labels(dataset):
    all_features = []
    all_labels = []
    for images, labels in dataset:
        preprocessed_images = keras.applications.vgg16.preprocess_input(images)
        features = conv_base.predict(preprocessed_images)
        all_features.append(features)
        all_labels.append(labels)
    return np.concatenate(all_features), np.concatenate(all_labels)

train_features, train_labels =  get_features_and_labels(train_dataset)
val_features, val_labels =  get_features_and_labels(validation_dataset)
test_features, test_labels =  get_features_and_labels(test_dataset)

# %%
train_features.shape
# Out:
# (2000, 5, 5, 512)

# %% [markdown]
# **Defining and training the densely connected classifier**

# %%
inputs = keras.Input(shape=(5, 5, 512))
x = layers.Flatten()(inputs)
x = layers.Dense(256)(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs, outputs)
model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

callbacks = [
    keras.callbacks.ModelCheckpoint(
      filepath="feature_extraction.keras",
      save_best_only=True,
      monitor="val_loss")
]
history = model.fit(
    train_features, train_labels,
    epochs=20,
    validation_data=(val_features, val_labels),
    callbacks=callbacks)
# Out:
# Epoch 1/20
# 63/63 [==============================] - 1s 7ms/step - loss: 18.8555 - accuracy: 0.9180 - val_loss: 4.5604 - val_accuracy: 0.9680
# Epoch 2/20
# 63/63 [==============================] - 0s 5ms/step - loss: 3.2630 - accuracy: 0.9765 - val_loss: 5.4007 - val_accuracy: 0.9750
# Epoch 3/20
# 63/63 [==============================] - 0s 5ms/step - loss: 2.2453 - accuracy: 0.9850 - val_loss: 8.8377 - val_accuracy: 0.9570
# Epoch 4/20
# 63/63 [==============================] - 0s 5ms/step - loss: 1.4423 - accuracy: 0.9885 - val_loss: 6.7369 - val_accuracy: 0.9650
# Epoch 5/20
# 63/63 [==============================] - 0s 6ms/step - loss: 1.4302 - accuracy: 0.9915 - val_loss: 4.6580 - val_accuracy: 0.9720
# Epoch 6/20
# 63/63 [==============================] - 0s 7ms/step - loss: 1.1372 - accuracy: 0.9945 - val_loss: 4.4583 - val_accuracy: 0.9790
# Epoch 7/20
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6116 - accuracy: 0.9950 - val_loss: 7.0523 - val_accuracy: 0.9750
# Epoch 8/20
# 63/63 [==============================] - 0s 6ms/step - loss: 0.7783 - accuracy: 0.9950 - val_loss: 6.6811 - val_accuracy: 0.9700
# Epoch 9/20
# 63/63 [==============================] - 0s 6ms/step - loss: 0.1344 - accuracy: 0.9990 - val_loss: 6.1704 - val_accuracy: 0.9750
# Epoch 10/20
# 63/63 [==============================] - 0s 6ms/step - loss: 0.1936 - accuracy: 0.9980 - val_loss: 5.6710 - val_accuracy: 0.9750
# Epoch 11/20
# 63/63 [==============================] - 0s 7ms/step - loss: 0.8121 - accuracy: 0.9935 - val_loss: 6.2524 - val_accuracy: 0.9700
# Epoch 12/20
# 63/63 [==============================] - 0s 6ms/step - loss: 0.2838 - accuracy: 0.9965 - val_loss: 6.5762 - val_accuracy: 0.9730
# Epoch 13/20
# 63/63 [==============================] - 0s 6ms/step - loss: 0.0232 - accuracy: 0.9995 - val_loss: 6.2768 - val_accuracy: 0.9770
# Epoch 14/20
# 63/63 [==============================] - 0s 6ms/step - loss: 0.0595 - accuracy: 0.9990 - val_loss: 7.4508 - val_accuracy: 0.9710
# Epoch 15/20
# 63/63 [==============================] - 0s 6ms/step - loss: 0.0498 - accuracy: 0.9985 - val_loss: 7.3439 - val_accuracy: 0.9720
# Epoch 16/20
# 63/63 [==============================] - 0s 6ms/step - loss: 0.0846 - accuracy: 0.9980 - val_loss: 8.9217 - val_accuracy: 0.9720
# Epoch 17/20
# 63/63 [==============================] - 0s 6ms/step - loss: 0.1375 - accuracy: 0.9995 - val_loss: 7.3188 - val_accuracy: 0.9760
# Epoch 18/20
# 63/63 [==============================] - 0s 6ms/step - loss: 4.1039e-10 - accuracy: 1.0000 - val_loss: 7.3003 - val_accuracy: 0.9760
# Epoch 19/20
# 63/63 [==============================] - 0s 6ms/step - loss: 0.1438 - accuracy: 0.9985 - val_loss: 8.9805 - val_accuracy: 0.9690
# Epoch 20/20
# 63/63 [==============================] - 0s 6ms/step - loss: 0.0205 - accuracy: 0.9990 - val_loss: 7.8639 - val_accuracy: 0.9740

# %% [markdown]
# **Plotting the results**

# %%
import matplotlib.pyplot as plt
acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(acc) + 1)
plt.plot(epochs, acc, "bo", label="Training accuracy")
plt.plot(epochs, val_acc, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %% [markdown]
# #### Feature extraction together with data augmentation

# %% [markdown]
# **Instantiating and freezing the VGG16 convolutional base**

# %%
conv_base  = keras.applications.vgg16.VGG16(
    weights="imagenet",
    include_top=False)
conv_base.trainable = False

# %% [markdown]
# **Printing the list of trainable weights before and after freezing**

# %%
conv_base.trainable = True
print("This is the number of trainable weights "
      "before freezing the conv base:", len(conv_base.trainable_weights))
# Out:
# This is the number of trainable weights before freezing the conv base: 26

# %%
conv_base.trainable = False
print("This is the number of trainable weights "
      "after freezing the conv base:", len(conv_base.trainable_weights))
# Out:
# This is the number of trainable weights after freezing the conv base: 0

# %% [markdown]
# **Adding a data augmentation stage and a classifier to the convolutional base**

# %%
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.1),
        layers.RandomZoom(0.2),
    ]
)

inputs = keras.Input(shape=(180, 180, 3))
x = data_augmentation(inputs)
x = keras.applications.vgg16.preprocess_input(x)
x = conv_base(x)
x = layers.Flatten()(x)
x = layers.Dense(256)(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs, outputs)
model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="feature_extraction_with_data_augmentation.keras",
        save_best_only=True,
        monitor="val_loss")
]
history = model.fit(
    train_dataset,
    epochs=50,
    validation_data=validation_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/50
# 63/63 [==============================] - 5s 63ms/step - loss: 16.8339 - accuracy: 0.8935 - val_loss: 4.8396 - val_accuracy: 0.9680
# Epoch 2/50
# 63/63 [==============================] - 4s 60ms/step - loss: 6.5974 - accuracy: 0.9495 - val_loss: 2.4764 - val_accuracy: 0.9740
# Epoch 3/50
# 63/63 [==============================] - 4s 59ms/step - loss: 6.3416 - accuracy: 0.9570 - val_loss: 3.3394 - val_accuracy: 0.9740
# Epoch 4/50
# 63/63 [==============================] - 4s 59ms/step - loss: 4.6801 - accuracy: 0.9640 - val_loss: 4.8078 - val_accuracy: 0.9730
# Epoch 5/50
# 63/63 [==============================] - 4s 58ms/step - loss: 5.4325 - accuracy: 0.9615 - val_loss: 6.7929 - val_accuracy: 0.9610
# Epoch 6/50
# 63/63 [==============================] - 4s 58ms/step - loss: 4.6885 - accuracy: 0.9625 - val_loss: 4.9974 - val_accuracy: 0.9710
# Epoch 7/50
# 63/63 [==============================] - 4s 58ms/step - loss: 3.4331 - accuracy: 0.9670 - val_loss: 2.7647 - val_accuracy: 0.9810
# Epoch 8/50
# 63/63 [==============================] - 4s 58ms/step - loss: 2.2447 - accuracy: 0.9810 - val_loss: 3.1302 - val_accuracy: 0.9810
# Epoch 9/50
# 63/63 [==============================] - 4s 59ms/step - loss: 2.7493 - accuracy: 0.9750 - val_loss: 2.4360 - val_accuracy: 0.9830
# Epoch 10/50
# 63/63 [==============================] - 4s 58ms/step - loss: 2.6549 - accuracy: 0.9740 - val_loss: 6.9842 - val_accuracy: 0.9560
# Epoch 11/50
# 63/63 [==============================] - 4s 60ms/step - loss: 2.6262 - accuracy: 0.9755 - val_loss: 2.1567 - val_accuracy: 0.9800
# Epoch 12/50
# 63/63 [==============================] - 4s 58ms/step - loss: 1.9382 - accuracy: 0.9785 - val_loss: 3.4307 - val_accuracy: 0.9720
# Epoch 13/50
# 63/63 [==============================] - 4s 59ms/step - loss: 2.2455 - accuracy: 0.9785 - val_loss: 3.4373 - val_accuracy: 0.9780
# Epoch 14/50
# 63/63 [==============================] - 4s 59ms/step - loss: 1.5934 - accuracy: 0.9810 - val_loss: 2.2407 - val_accuracy: 0.9820
# %%
conv_base.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_8 (InputLayer)        [(None, None, None, 3)]   0
#
#  block1_conv1 (Conv2D)       (None, None, None, 64)    1792
#
#  block1_conv2 (Conv2D)       (None, None, None, 64)    36928
#
#  block1_pool (MaxPooling2D)  (None, None, None, 64)    0
#
#  block2_conv1 (Conv2D)       (None, None, None, 128)   73856
#
#  block2_conv2 (Conv2D)       (None, None, None, 128)   147584
#
#  block2_pool (MaxPooling2D)  (None, None, None, 128)   0
#
#  block3_conv1 (Conv2D)       (None, None, None, 256)   295168
#
#  block3_conv2 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_conv3 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_pool (MaxPooling2D)  (None, None, None, 256)   0
#
#  block4_conv1 (Conv2D)       (None, None, None, 512)   1180160
#
#  block4_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_conv3 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_pool (MaxPooling2D)  (None, None, None, 512)   0
#
#  block5_conv1 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv3 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_pool (MaxPooling2D)  (None, None, None, 512)   0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %% [markdown]
# **Freezing all layers until the fourth from the last**

# %%
conv_base.trainable = True
for layer in conv_base.layers[:-4]:
    layer.trainable = False

# %% [markdown]
# **Fine-tuning the model**

# %%
model.compile(loss="binary_crossentropy",
              optimizer=keras.optimizers.RMSprop(learning_rate=1e-5),
              metrics=["accuracy"])

callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="fine_tuning.keras",
        save_best_only=True,
        monitor="val_loss")
]
history = model.fit(
    train_dataset,
    epochs=30,
    validation_data=validation_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/30
# 63/63 [==============================] - 5s 62ms/step - loss: 0.4021 - accuracy: 0.9905 - val_loss: 1.5532 - val_accuracy: 0.9760
# Epoch 2/30
# 63/63 [==============================] - 4s 60ms/step - loss: 0.2687 - accuracy: 0.9925 - val_loss: 1.5225 - val_accuracy: 0.9750
# Epoch 3/30
# 63/63 [==============================] - 4s 58ms/step - loss: 0.2362 - accuracy: 0.9910 - val_loss: 2.0395 - val_accuracy: 0.9700
# Epoch 4/30
# 63/63 [==============================] - 4s 60ms/step - loss: 0.2426 - accuracy: 0.9910 - val_loss: 1.5181 - val_accuracy: 0.9770
# Epoch 5/30
# 63/63 [==============================] - 4s 60ms/step - loss: 0.3553 - accuracy: 0.9895 - val_loss: 1.1859 - val_accuracy: 0.9780
# Epoch 6/30
# 63/63 [==============================] - 4s 58ms/step - loss: 0.1124 - accuracy: 0.9935 - val_loss: 1.5029 - val_accuracy: 0.9760
# Epoch 7/30
# 63/63 [==============================] - 4s 58ms/step - loss: 0.2164 - accuracy: 0.9915 - val_loss: 1.2713 - val_accuracy: 0.9810
# Epoch 8/30
# 63/63 [==============================] - 4s 61ms/step - loss: 0.1422 - accuracy: 0.9940 - val_loss: 1.5615 - val_accuracy: 0.9750
# Epoch 9/30
# 63/63 [==============================] - 4s 64ms/step - loss: 0.1260 - accuracy: 0.9920 - val_loss: 1.5239 - val_accuracy: 0.9810
# Epoch 10/30
# 63/63 [==============================] - 4s 64ms/step - loss: 0.1617 - accuracy: 0.9935 - val_loss: 1.4057 - val_accuracy: 0.9790
# Epoch 11/30
# 63/63 [==============================] - 4s 64ms/step - loss: 0.2189 - accuracy: 0.9945 - val_loss: 2.5631 - val_accuracy: 0.9660
# Epoch 12/30
# 63/63 [==============================] - 4s 64ms/step - loss: 0.0954 - accuracy: 0.9950 - val_loss: 1.8729 - val_accuracy: 0.9730
# Epoch 13/30
